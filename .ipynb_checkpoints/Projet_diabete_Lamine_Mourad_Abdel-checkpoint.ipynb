# %% [markdown]
# # Pima Indians Diabetes Database
# https://www.kaggle.com/uciml/pima-indians-diabetes-database

# %% [raw]
# Cet ensemble de données est à l'origine de l'Institut national du diabète et des maladies digestives et rénales.
# Il est fourni avec l'aimable autorisation de la base de données sur le diabète des Indiens Pima et est disponible sur Kaggle:
# Il se compose de plusieurs variables prédictives médicales et d'une variable cible, le résultat.
# Les variables prédictives comprennent le nombre de grossesses que la patiente a eues, son IMC, son taux d'insuline, son âge, etc.
#
# L'ensemble de données comporte 9 colonnes, comme indiqué ci-dessous;
#
#   Pregnancies              - Nombre de fois enceinte
#   Glucose                  - Concentration de glucose plasmatique à 2 heures dans un test oral de tolérance au glucose
#   BloodPressure            - Tension artérielle diastolique (mm Hg)
#   SkinThickness            - Épaisseur du pli cutané du triceps (mm)
#   Insulin                  - Insuline sérique 2 heures (mu U / ml)
#   BMI                      - Indice de masse corporelle (poids en kg / (taille en m) ^ 2)
#   DiabetesPedigreeFunction - Fonction généalogique du diabète
#   Age                            - Années d'âge)
#   Outcome                  - Variable de classe (0 ou 1) 268 sur 768 sont 1, les autres sont 0
#
#
#
# Énoncé du problème
#
# Il s'agit d'un problème de classification de l'apprentissage automatique supervisé.
# L'objectif est de prédire si un patient est diabétique ou non, sur la base de certaines mesures diagnostiques incluses dans l'ensemble de données.
#
# 0 - Absence de diabète
#
# 1 - Présence de diabète
#
#
#
# Dans ce projet, nous utilisonsons python3 et le notebook Jupyter.
# Nous allons parcourir le projet en important l'ensemble de données, en effectuant une analyse exploratoire des données pour obtenir des informations et comprendre à quoi ressemble l'ensemble de données, puis construire le modèle.
# Nous utilisonsons en outre .
#
# Les 7 étapes de l'apprentissage automatique , fournit le cadre général suivant des étapes de l'apprentissage automatique supervisé;
#
#     Collecte de données
#     Préparation des données
#     Choisir un modèle
#     Entraîner le modèle
#     Évaluer le modèle
#     Réglage des paramètres
#     Faire des prédictions
#
# Commençons donc par importer les bibliothèques requises.
# Nous importons des bibliothèques d'analyse de données ( pandas, numpy) et des bibliothèques de visualisation ( matplotlib, seaborn).
# En plus de cela, nous importons également warnings afin que les avertissements soient masqués du notebook au cas où il y en aurait.
# Pour résoudre le problème, nous devrons analyser les données, effectuer toute transformation et normalisation requises, appliquer un algorithme d'apprentissage automatique, entraîner un modèle, vérifier les performances du modèle entraîné et itérer avec d'autres algorithmes jusqu'à ce que nous trouvions le plus performant pour notre type. de l'ensemble de données.

# %% [markdown]
# ___

# %%
# importer les librairies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importer les librairies machine learning

# %%
# importer la base de données
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# vérifier les valeurs null
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# voir la description du dataset
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# voir les informations sur le dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Visuel sur la variable 'Outcome' (diabétique=1 ; NON diabétiques=0)
sns.countplot(df['Outcome'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap (df.corr(), annot = True)

# %%
df.groupby("Outcome").hist(figsize=(9, 9))
# Out:
# Outcome
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
#Check columns with zero values

print("Total number of rows: {0}", format(len(df)))
print("Number of rows missing Pregnancies: {0}",
      format(len(df.loc[df['Pregnancies']==0])))
print("Number of rows missing Glucose: {0}"
      , format(len(df.loc[df['Glucose']==0])))
print("Number of rows missing BloodPressure: {0}",
      format(len(df.loc[df['BloodPressure']==0])))
print("Number of rows missing SkinThickness: {0}",
      format(len(df.loc[df['SkinThickness']==0])))
print("Number of rows missing Insulin: {0}",
      format(len(df.loc[df['Insulin']==0])))
print("Number of rows missing BMI: {0}",
      format(len(df.loc[df['BMI']==0])))
print("Number of rows missing DiabetesPedigreeFunction: {0}",
      format(len(df.loc[df['DiabetesPedigreeFunction']==0])))
print("Number of rows missing Age: {0}", format(len(df.loc[df['Age']==0])))
# Out:
# Total number of rows: {0} 768
# Number of rows missing Pregnancies: {0} 111
# Number of rows missing Glucose: {0} 5
# Number of rows missing BloodPressure: {0} 35
# Number of rows missing SkinThickness: {0} 227
# Number of rows missing Insulin: {0} 374
# Number of rows missing BMI: {0} 11
# Number of rows missing DiabetesPedigreeFunction: {0} 0
# Number of rows missing Age: {0} 0

# %%
# Calculez la valeur médiane de l'IMC 
median_bmi  =  df [ 'BMI' ] . median () 
# Remplacez-le dans la colonne BMI du 
# dataset où les valeurs sont 0 
df [ 'BMI' ]  =  df [ 'BMI' ] . replace ( 
    to_replace = 0 ,  value = median_bmi )

# Calculez la valeur médiane de BloodP 
median_BloodPressure  =  df [ 'BloodPressure' ] . median () 
# Remplacez-le dans la colonne BloodPressure du 
# dataset où les valeurs sont 0 
df [ 'BloodPressure' ]  =  df [ 'BloodPressure' ] . replace ( 
    to_replace = 0 ,  value = median_BloodPressure )

# Calculez la valeur médiane de PlGlcConc 
median_SkinThickness  =  df [ 'SkinThickness' ] . median () 
# Remplacez-le dans la colonne SkinThickness du 
# dataset où les valeurs sont 0 
df [ 'SkinThickness' ]  =  df [ 'SkinThickness' ] . replace ( 
    to_replace = 0 ,  value = median_SkinThickness )

# Calculez la valeur médiane de SkinThick 
median_Insulin  =  df [ 'Insulin' ] . median () 
# Remplacez-le dans la colonne Insulin du 
# dataset où les valeurs sont 0 
df [ 'Insulin' ]  =  df [ 'Insulin' ] . replace ( 
    to_replace = 0 ,  value = median_Insulin )

# Calculez la valeur médiane de Glucose 
median_Glucose  =  df [ 'Glucose' ] . median () 
# Remplacez-le dans la colonne Glucose du 
# dataset où les valeurs sont 0 
df [ 'Glucose' ]  =  df [ 'Glucose' ] . replace ( 
    to_replace = 0 ,  value = median_Glucose )

# %%
IMC = ['BMI']
BP = ['BloodPressure']
Ins = ['Insulin']
GLUC = ['Glucose']


fig = plt.figure(figsize=(15,10))
#2 rows 2 cols
#first row, first col
ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(IMC.BMI,colors=("grey","r","orange"),labels=label1, autopct='%.2f',textprops={'fontsize': 14, 'weight':'bold'})
plt.title('BMI',weight='bold', fontsize=18)
#first row sec col
ax1 = plt.subplot2grid((2,2), (0, 1))
plt.pie(BP.BloodPressure,colors=("grey","r","orange"),labels=label2, autopct='%.2f',textprops={'fontsize': 14, 'weight':'bold'})
plt.title('BloodPressure',weight='bold', fontsize=18)
#Second row first column
ax1 = plt.subplot2grid((2,2), (1, 0))
plt.pie(Ins.Insulin,colors=("grey","r","orange"),labels=label3, autopct='%.2f',textprops={'fontsize': 14, 'weight':'bold'})
plt.title('Insulin',weight='bold', fontsize=18)
#second row second column
ax1 = plt.subplot2grid((2,2), (1, 1))
plt.pie(GLUC.Glucose,colors=("grey","r","orange"),labels=label4, autopct='%.2f',textprops={'fontsize': 14, 'weight':'bold'})
plt.title('Glucose',weight='bold', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-842cc181e78a> in <module>
#       9 #first row, first col
#      10 ax1 = plt.subplot2grid((2,2),(0,0))
# ---> 11 plt.pie(IMC.BMI,colors=("grey","r","orange"),labels=label1, autopct='%.2f',textprops={'fontsize': 14, 'weight':'bold'})
#      12 plt.title('BMI',weight='bold', fontsize=18)
#      13 #first row sec col
#
# AttributeError: 'list' object has no attribute 'BMI'
